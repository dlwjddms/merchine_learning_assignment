# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, color='blue')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# - feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    distance = np.array([np.sum(np.power((np.array(center)-np.array(f)),2)) for f in feature])


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return distance
#compute_distance([[1,2],[3,4],[6,7]],[1,1])

# %% [markdown]
# ## compute centroid
# - feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# - $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, label):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    feature = np.array(feature)
    label_feature = np.array(label_feature)
  
    centroid = np.mean(feature[np.where(label_feature==label)], axis=0)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

    return centroid
#compute_centroid(np.array([[1,2],[3,4],[5,6]]),np.array([0,1,0]),0)

# %% [markdown]
# ## compute label
# - distance : $n \times k$, label_feature : $n \times 1$
# - $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    distance = np.array(distance)
    #print(distance)
    label_feature = np.argmin(distance ,axis=0)
    #print(label_feature)
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    
    return label_feature
#print(np.array([[1,2,3],[3,2,1]]).shape)
#compute_label([[1,2,3],[3,2,1]])

# %% [markdown]
# ## the number of clusters $K = 2$

# %%
number_cluster          = 2
number_iteration        = 100     # you can modify this value
loss_iteration_02       = np.zeros(number_iteration)
centroid_iteration_02   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_02        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(0, number_iteration):
    for label in range(0, number_cluster):
        if len(np.extract(label_feature_02==label, label_feature_02)):
            centroid_iteration_02[i,label,:] = compute_centroid(feature, label_feature_02, label) 
        else: centroid_iteration_02[i,label,:] =  centroid_iteration_02[i-1,label,:]
   
    loss_iteration_02[i] = np.sum(np.array([np.sum(compute_distance(feature[np.where(label_feature_02==ind)], center)) for ind, center in enumerate(centroid_iteration_02[i])]))/number_data

  
    label_feature_02 = compute_label(np.array([compute_distance(feature, center) for center in centroid_iteration_02[i]]))
    #print(label_feature_02)
    #print( loss_iteration_02[i])
    #if i > 0: 
     #   if np.all(centroid_iteration_02[i-1,:]== centroid_iteration_02[i,:]): break
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 4$

# %%
number_cluster          = 4
number_iteration        = 100     # you can modify this value
loss_iteration_04       = np.zeros(number_iteration)
centroid_iteration_04   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_04        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(0, number_iteration):
    for label in range(0, number_cluster):
        if len(np.extract(label_feature_04==label, label_feature_04)):
            centroid_iteration_04[i,label,:] = compute_centroid(feature, label_feature_04, label) 
        else: centroid_iteration_04[i,label,:] =  centroid_iteration_04[i-1,label,:]
   
    loss_iteration_04[i] = np.sum(np.array([np.sum(compute_distance(feature[np.where(label_feature_04==ind)], center)) for ind, center in enumerate(centroid_iteration_04[i])]))/number_data

  
    label_feature_04 = compute_label(np.array([compute_distance(feature, center) for center in centroid_iteration_04[i]]))
    #print(label_feature_02)
    #print( loss_iteration_02[i])
    #if i > 0: 
    #    if np.all(centroid_iteration_04[i-1,:]== centroid_iteration_04[i,:]): break

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 8$

# %%
number_cluster          = 8
number_iteration        = 100     # you can modify this value
loss_iteration_08       = np.zeros(number_iteration)
centroid_iteration_08   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_08        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#

for i in range(0, number_iteration):
    for label in range(0, number_cluster):
        if len(np.extract(label_feature_08==label, label_feature_08)):
            centroid_iteration_08[i,label,:] = compute_centroid(feature, label_feature_08, label) 
        else: centroid_iteration_08[i,label,:] =  centroid_iteration_08[i-1,label,:]
   
    loss_iteration_08[i] = np.sum(np.array([np.sum(compute_distance(feature[np.where(label_feature_08==ind)], center)) for ind, center in enumerate(centroid_iteration_08[i])]))/number_data

  
    label_feature_08 = compute_label(np.array([compute_distance(feature, center) for center in centroid_iteration_08[i]]))
    #print(label_feature_02)
    #print( loss_iteration_08[i])
    #if i > 0: 
     #   if np.all(centroid_iteration_08[i-1,:]== centroid_iteration_08[i,:]): break

#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## the number of clusters $K = 16$

# %%
number_cluster          = 16
number_iteration        = 100     # you can modify this value
loss_iteration_16       = np.zeros(number_iteration)
centroid_iteration_16   = np.zeros((number_iteration, number_cluster, number_feature))
label_feature_16        = np.random.randint(0, number_cluster, size=(number_data))

# %%
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# complete the blanks
#
for i in range(0, number_iteration):
    for label in range(0, number_cluster):
        if len(np.extract(label_feature_16==label, label_feature_16)):
            centroid_iteration_16[i,label,:] = compute_centroid(feature, label_feature_16, label) 
        else: centroid_iteration_16[i,label,:] =  centroid_iteration_16[i-1,label,:]
   
    loss_iteration_16[i] = np.sum(np.array([np.sum(compute_distance(feature[np.where(label_feature_16==ind)], center)) for ind, center in enumerate(centroid_iteration_16[i])]))/number_data

  
    label_feature_16 = compute_label(np.array([compute_distance(feature, center) for center in centroid_iteration_16[i]]))
    #print(label_feature_02)
    #print( loss_iteration_16[i])
    #if i > 0: 
     #   if np.all(centroid_iteration_16[i-1,:]== centroid_iteration_16[i,:]): break


#
# ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## functions for presenting the results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
def function_result_01():

    print("final loss (K=2) = {:13.10f}".format(loss_iteration_02[-1]))

# %%
def function_result_02():

    print("final loss (K=4) = {:13.10f}".format(loss_iteration_04[-1]))

# %%
def function_result_03():

    print("final loss (K=8) = {:13.10f}".format(loss_iteration_08[-1]))

# %%
def function_result_04():

    print("final loss (K=16) = {:13.10f}".format(loss_iteration_16[-1]))

# %%
def function_result_05():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=2)')

    plt.plot(loss_iteration_02, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_06():
    
    plt.figure(figsize=(8,6)) 
    plt.title('loss (K=4)')

    plt.plot(loss_iteration_04, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_07():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=8)')

    plt.plot(loss_iteration_08, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_08():
    
    plt.figure(figsize=(8,6))
    plt.title('loss (K=16)')

    plt.plot(loss_iteration_16, '-', color='red')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    
    plt.tight_layout()
    plt.show()

# %%
def function_result_09():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    x = feature[:,0]
    y = feature[:,1]
    #print(centroid_iteration_02.shape) # i label pint

    for label in range(0,2):
        plt.plot(centroid_iteration_02[:, label,0], centroid_iteration_02[:, label,1])

    plt.scatter(centroid_iteration_02[0][:,0], centroid_iteration_02[0][:,1], c='red')
    plt.scatter(centroid_iteration_02[-1][:,0], centroid_iteration_02[-1][:,1], c='blue')
    plt.tight_layout()
    plt.show()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
function_result_09()

# %%
def function_result_10():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    for label in range(0,4):
        plt.plot(centroid_iteration_04[:, label,0], centroid_iteration_04[:, label,1])

    plt.scatter(centroid_iteration_04[0][:,0], centroid_iteration_04[0][:,1], c='red')
    plt.scatter(centroid_iteration_04[-1][:,0], centroid_iteration_04[-1][:,1], c='blue')
    plt.tight_layout()
    plt.show()
function_result_10()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_11():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    for label in range(0,8):
        plt.plot(centroid_iteration_08[:, label,0], centroid_iteration_08[:, label,1])

    plt.scatter(centroid_iteration_08[0][:,0], centroid_iteration_08[0][:,1], c='red')
    plt.scatter(centroid_iteration_08[-1][:,0], centroid_iteration_08[-1][:,1], c='blue')
    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_12():

    plt.figure(figsize=(8,8))
    plt.title('centroid (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #


    for label in range(0,16):
        plt.plot(centroid_iteration_16[:, label,0], centroid_iteration_16[:, label,1])

    plt.scatter(centroid_iteration_16[0][:,0], centroid_iteration_16[0][:,1], c='red')
    plt.scatter(centroid_iteration_16[-1][:,0], centroid_iteration_16[-1][:,1], c='blue')
    plt.tight_layout()
    plt.show()
    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_13():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=2)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, c=label_feature_02,label=label_feature_02)

    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++
#function_result_13()

# %%
def function_result_14():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=4)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, c=label_feature_04,label=label_feature_04)

    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_15():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=8)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #
    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, c=label_feature_08,label=label_feature_08)

    plt.tight_layout()
    plt.show()


    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def function_result_16():

    plt.figure(figsize=(8,8))
    plt.title('cluster (K=16)')

    # ++++++++++++++++++++++++++++++++++++++++++++++++++
    # complete the blanks
    #

    x = feature[:,0]
    y = feature[:,1]
    
    plt.scatter(x, y, c=label_feature_16,label=label_feature_16)

    plt.tight_layout()
    plt.show()

    #
    # ++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## results

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
number_result = 16

for i in range(number_result):
    title = '## [RESULT {:02d}]'.format(i+1)
    name_function = 'function_result_{:02d}()'.format(i+1)

    print('**************************************************')
    print(title)
    print('**************************************************')
    eval(name_function)
# Out:
# **************************************************
# ## [RESULT 01]
# **************************************************
# final loss (K=2) = 31.1123356206
# **************************************************
# ## [RESULT 02]
# **************************************************
# final loss (K=4) = 10.5831291650
# **************************************************
# ## [RESULT 03]
# **************************************************
# final loss (K=8) =  5.6814980416
# **************************************************
# ## [RESULT 04]
# **************************************************
# final loss (K=16) =  3.3068592842
# **************************************************
# ## [RESULT 05]
# **************************************************
# **************************************************
# ## [RESULT 06]
# **************************************************
# **************************************************
# ## [RESULT 07]
# ...
